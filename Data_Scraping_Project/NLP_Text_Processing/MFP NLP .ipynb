# %%
# import libraries 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings 
warnings.filterwarnings('ignore')
import nltk
import string

# %% [markdown]
# # Load Data

# %%
raw_data = pd.read_csv('mfp_data.csv')
raw_data.head(10)
# Out:
#                 user                     date  \
# 0              avskk  October 24, 2018 2:32PM
# 1      janejellyroll  October 24, 2018 2:37PM
# 2         firlena227  October 24, 2018 4:07PM
# 3           amy19355  November 2, 2018 3:30PM
# 4  Sunshine_And_Sand  November 2, 2018 3:38PM
# 5              avskk  November 2, 2018 4:42PM
# 6        MelanieCN77  November 3, 2018 2:00PM
# 7   nicsflyingcircus  November 3, 2018 4:31PM
# 8        MelanieCN77  November 3, 2018 5:10PM
# 9     rainingribbons  November 3, 2018 8:01PM
#
#                                                 post
# 0  Autumn has fully arrived and I'm cooking about...
# 1  Breakfast:\nChinese sticky rice with tempeh sa...
# 2  Ooh I love butternut squash risotto (apart fro...
# 3  Can of low sodium chicken\nwith wild rice soup...
# 4  Breakfast - zoats with melted American cheese ...
# 5  Today's going to be a good, if carby, day, I t...
# 6  Breakfast: home made plain yoghurt with bluebe...
# 7  Breakfast: the Protein Plate at our local dine...
# 8  OK well my nice plan went out the window. I'm ...
# 9  Breakfast: 2 homemade cinnamon rolls\nMorning ...

# %%
raw_data.dtypes
# Out:
# user    object
# date    object
# post    object
# dtype: object

# %%
raw_data.columns
# Out:
# Index(['user', 'date', 'post'], dtype='object')

# %%
raw_data.shape
# Out:
# (21, 3)

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   user    21 non-null     object
#  1   date    21 non-null     object
#  2   post    21 non-null     object
# dtypes: object(3)
# memory usage: 632.0+ bytes

# %% [markdown]
# # Text Processing (NLP)

# %% [markdown]
# **Convert to LowerCase**

# %%
raw_data['post'] = [post.lower() for post in raw_data['post']]

print(raw_data['post'])
# Out:
# 0     autumn has fully arrived and i'm cooking about...
# 1     breakfast:\nchinese sticky rice with tempeh sa...
# 2     ooh i love butternut squash risotto (apart fro...
# 3     can of low sodium chicken\nwith wild rice soup...
# 4     breakfast - zoats with melted american cheese ...
# 5     today's going to be a good, if carby, day, i t...
# 6     breakfast: home made plain yoghurt with bluebe...
# 7     breakfast: the protein plate at our local dine...
# 8     ok well my nice plan went out the window. i'm ...
# 9     breakfast: 2 homemade cinnamon rolls\nmorning ...
# 10    it's my birthday, so i ate all of the things a...
# 11    seltzermint555\nwrote:\n»\nit's my birthday, s...
# 12    breakfast:\nchickpea soup with rice and kale, ...
# 13    breakfast:\ncranberry muffin with a little yog...
# 14    avskk\nwrote:\n»\nseltzermint555\nwrote:\n»\ni...
# 15    my big bowl for lunch today combined:\n1/2 cup...
# 16    no breakfast, my usual brunch: 110 calorie eng...
# 17    breakfast: fried egg open faced sandwich on wh...
# 18    i had a killer breakfast this morning -- i cub...
# 19    i've been hoarding calories for dessert/after ...
# 20    breakfast: cup of hot cocoa\nsnack 1: half pea...
# Name: post, dtype: object

# %% [markdown]
# **Tokenization**

# %%
# word tokenization 

from nltk.tokenize import word_tokenize
token_post = [word_tokenize(post) for post in raw_data['post']]
print(token_post)

print('-------------------------------------------')

# sentence tokenization

from nltk.tokenize import sent_tokenize
sent_token = [sent_tokenize(post) for post in raw_data['post']]
print(sent_token)
# Out:
# [['autumn', 'has', 'fully', 'arrived', 'and', 'i', "'m", 'cooking', 'about', 'it', '.', 'breakfast', ':', 'toaster', 'waffles', 'with', 'yogurt', 'butter', 'and', 'syrup', ',', 'fried', 'ham', ',', 'coffee', '.', 'lunch', ':', 'leftover', 'chili', 'with', 'cheese', ',', 'sour', 'cream', ',', 'and', 'a', 'few', 'corn', 'chips', '.', 'i', "'m", 'having', 'a', 'fairly', 'small', 'portion', 'of', 'this', '(', 'it', "'s", '...', 'not', 'at', 'all', '``', 'light', "''", ')', ',', 'so', 'if', 'i', "'m", 'still', 'hungry', 'i', "'ll", 'have', 'some', 'broccoli', ',', 'baby', 'carrots', ',', 'and', 'cherry', 'tomatoes', '.', 'dinner', ':', 'leftover', 'vegetable-loaded', 'chicken-tortellini', 'soup', '.', 'snacks', ':', 'clementines', ',', 'grapes', ',', 'or', 'pomegranate', '.'], ['breakfast', ':', 'chinese', 'sticky', 'rice', 'with', 'tempeh', 'sausage', ',', 'cucumber', 'salad', 'lunch', ':', 'going', 'out', 'to', 'lunch', 'with', 'co-workers', '.', '.', '.', 'probably', 'a', 'black', 'bean', 'burger', 'with', 'guacamole', 'and', 'some', 'fruit', 'salad', 'dinner', ':', 'lettuce', ',', 'basil', ',', 'mint', ',', 'and', 'radishes', 'with', 'thai-style', 'dressing', ',', 'sweet', 'potato', 'stew', 'i', 'love', 'autumn', 'cooking', '!', 'i', 'just', 'got', 'some', 'butternut', 'squash', 'in', 'my', 'csa', 'box', 'so', 'i', "'m", 'thinking', 'about', 'what', 'i', 'want', 'to', 'do', 'with', 'them', 'this', 'weekend', '(', 'thinking', 'maybe', 'roasted', 'butternut', 'squash', 'risotto', ')', '.'], ['ooh', 'i', 'love', 'butternut', 'squash', 'risotto', '(', 'apart', 'from', 'the', 'chopping', 'up', 'the', 'butternut', 'squash', 'part', '!', '!', ')', 'have', "n't", 'made', 'it', 'for', 'ages', ',', 'that', "'s", 'definitely', 'going', 'on', 'my', 'next', 'week', "'s", 'menu', 'breakfast', ':', 'crumpets', ',', 'banana', '.', 'lunch', ':', 'cheese', '&', 'shallot', 'toastie', ',', 'apple', 'dinner', ':', 'jacket', 'potato', '&', 'beans', '.', 'not', 'the', 'most', 'inspiring', 'food', 'day', 'today', '!'], ['can', 'of', 'low', 'sodium', 'chicken', 'with', 'wild', 'rice', 'soup', ',', 'with', 'an', 'added', '1/2', 'cup', 'of', 'brown', 'rice', 'and', 'a', 'side', 'of', 'crunchy', 'raw', 'organic', 'carrots', '.'], ['breakfast', '-', 'zoats', 'with', 'melted', 'american', 'cheese', 'and', 'salt', 'and', 'pepper', 'lunch', '-', 'amy', "'s", 'organic', 'tortilla', 'casserole', 'and', 'black', 'beans', 'microwave', 'dinner', 'with', 'the', 'rest', 'of', 'the', 'zucchini', 'from', 'breakfast', 'mixed', 'in', 'for', 'added', 'volume', 'dinner', '-', '1', 'oz', 'pasta', 'with', 'roasted', 'orange', 'bell', 'pepper', ',', 'steamed', 'corn', 'and/or', 'peas', 'if', 'i', 'have', 'them', ',', 'and', 'about', 'an', 'ounce', 'of', 'shredded', 'cheese', '.', 'side', 'of', 'steamed', 'asparagus', '(', 'i', 'buy', 'the', 'microwave', 'steam', 'in', 'bag', 'asparagus', 'and', 'dh', 'and', 'i', 'usually', 'eat', 'a', 'whole', 'bag', 'each', '😬', ')', 'snacks', '-', 'not', 'sure', 'yet', '...', 'thinking', 'of', 'trying', 'an', 'angel', 'food', 'cake', 'recipe', 'i', 'found', 'yesterday'], ['today', "'s", 'going', 'to', 'be', 'a', 'good', ',', 'if', 'carby', ',', 'day', ',', 'i', 'think', '.', 'breakfast', ':', 'about', '2/3', 'of', 'a', 'carrot', 'muffin', '(', 'amazing', ')', ',', 'cottage', 'cheese', 'with', 'peach', 'bellini', 'jam', ',', 'coffee', '.', 'lunch', ':', 'will', 'be', 'turkey', 'and', 'cheddar', 'sandwiches', 'on', 'green-chili', 'sourdough', '(', 'double', 'amazing', ')', ',', 'and', 'i', 'suspect', 'i', 'will', 'also', 'eat', 'at', 'least', 'one', 'slice', 'of', 'the', 'bread', 'topped', 'with', 'a', 'thin', 'slice', 'of', 'cheese', ';', 'baby', 'carrots', 'and', 'cherry', 'tomatoes', 'on', 'the', 'side', '.', 'dinner', ':', 'either', 'leftover', 'spanish', 'rice', 'with', 'chickpeas', ',', 'artichoke', 'hearts', ',', 'and', 'greens', '...', 'or', ',', 'let', "'s", 'be', 'honest', ',', 'more', 'fancy', 'bread', ',', 'cheese', ',', 'and', ' ...
# -------------------------------------------
# [["autumn has fully arrived and i'm cooking about it.", 'breakfast:\ntoaster waffles with yogurt butter and syrup, fried ham, coffee.', 'lunch:\nleftover chili with cheese, sour cream, and a few corn chips.', 'i\'m having a fairly small portion of this (it\'s... not at all "light"), so if i\'m still hungry i\'ll have some broccoli, baby carrots, and cherry tomatoes.', 'dinner:\nleftover vegetable-loaded chicken-tortellini soup.', 'snacks:\nclementines, grapes, or pomegranate.'], ['breakfast:\nchinese sticky rice with tempeh sausage, cucumber salad\nlunch\n: going out to lunch with co-workers .', '.', '.', 'probably a black bean burger with guacamole and some fruit salad\ndinner:\nlettuce, basil, mint, and radishes with thai-style dressing, sweet potato stew\ni love autumn cooking!', "i just got some butternut squash in my csa box so i'm thinking about what i want to do with them this weekend (thinking maybe roasted butternut squash risotto)."], ['ooh i love butternut squash risotto (apart from the chopping up the butternut squash part!!)', "haven't made it for ages, that's definitely going on my next week's menu\nbreakfast: crumpets, banana.", 'lunch: cheese & shallot toastie, apple\ndinner: jacket potato & beans.', 'not the most inspiring food day today!'], ['can of low sodium chicken\nwith wild rice soup, with an added 1/2 cup of brown rice and a side of crunchy raw organic carrots.'], ["breakfast - zoats with melted american cheese and salt and pepper\nlunch - amy's organic tortilla casserole and black beans microwave dinner with the rest of the zucchini from breakfast mixed in for added volume\ndinner - 1 oz pasta with roasted orange bell pepper, steamed corn and/or peas if i have them, and about an ounce of shredded cheese.", 'side of steamed asparagus (i buy the microwave steam in bag asparagus and dh and i usually eat a whole bag each 😬)\nsnacks - not sure yet... thinking of trying an angel food cake recipe i found yesterday'], ["today's going to be a good, if carby, day, i think.", 'breakfast:\nabout 2/3 of a carrot muffin (amazing), cottage cheese with peach bellini jam, coffee.', 'lunch:\nwill be turkey and cheddar sandwiches on green-chili sourdough (double amazing), and i suspect i will also eat at least one slice of the bread topped with a thin slice of cheese; baby carrots and cherry tomatoes on the side.', "dinner:\neither leftover spanish rice with chickpeas, artichoke hearts, and greens... or, let's be honest, more fancy bread, cheese, and turkey with a token side of green beans or broccoli."], ['breakfast: home made plain yoghurt with blueberries, strawberries and a handful of kashi granola, two cups of coffee\npost run snack: bunch of tangerines\nlunch: sausage and bell peppers baked in the oven, and a pita.', "i might add some sweet potato, we'll see.", "snacks: out and about so tub with carrots, cheese, grapes, nuts, crackers\ndinner: i'm getting home on the late side so if i'm crazy hungry i might pick something up and to hell with the cals today.", 'been thinking about a tostada salad and a quesadilla from el pollo loco all week lol.', 'or if i make it home with my discipline intact, some microwave rice, frozen gyoza and broccoli.', "late night munchies: all week instead of halo top or whatever, because it's been colder, been enjoying a little bowl of sliced apples, walnuts or cashews, couple chunks parmesan and some crackers."], ['breakfast: the protein plate at our local diner.', '4 scrambled eggs, 3 pieces of bacon, 2 slices of canadian bacon.', 'i could only eat half the eggs, lol.', 'supper: grilled cheese (on cauliflower sandwich thins), stuffed full with garlic and pepper ham, a little bacon, provolone and cheddar.', 'nice big salad with balsamic vinaigrette.'], ['ok well my nice plan went out the window.', "i'm having a 10am roast beef sandwich and crackers.", 'the runger is real.'], ['breakfast: 2 homemade cinnamon rolls\nmorning snack: another cinnamon roll.', 'late lunch/early dinner: roast, b ...

# %% [markdown]
# **Remove Punctuation**

# %%
# remove punctuation 

import re

# reg strips URL, punctuations, usernames, 
# and non alphanumeric characters. 
# Also separates words into single space

reg = re.compile('(@[a-z0-9]+)|([^0-9a-z \t])|(\w+:\/\/\S+)')

no_punc = []

for filt in token_post:
    review = []
    for token in filt:
        new_token = reg.sub(u'', token)
        if not new_token == u'':
            review.append(new_token)
    no_punc.append(review)
    
print(no_punc)
# Out:
# [['autumn', 'has', 'fully', 'arrived', 'and', 'i', 'm', 'cooking', 'about', 'it', 'breakfast', 'toaster', 'waffles', 'with', 'yogurt', 'butter', 'and', 'syrup', 'fried', 'ham', 'coffee', 'lunch', 'leftover', 'chili', 'with', 'cheese', 'sour', 'cream', 'and', 'a', 'few', 'corn', 'chips', 'i', 'm', 'having', 'a', 'fairly', 'small', 'portion', 'of', 'this', 'it', 's', 'not', 'at', 'all', 'light', 'so', 'if', 'i', 'm', 'still', 'hungry', 'i', 'll', 'have', 'some', 'broccoli', 'baby', 'carrots', 'and', 'cherry', 'tomatoes', 'dinner', 'leftover', 'vegetableloaded', 'chickentortellini', 'soup', 'snacks', 'clementines', 'grapes', 'or', 'pomegranate'], ['breakfast', 'chinese', 'sticky', 'rice', 'with', 'tempeh', 'sausage', 'cucumber', 'salad', 'lunch', 'going', 'out', 'to', 'lunch', 'with', 'coworkers', 'probably', 'a', 'black', 'bean', 'burger', 'with', 'guacamole', 'and', 'some', 'fruit', 'salad', 'dinner', 'lettuce', 'basil', 'mint', 'and', 'radishes', 'with', 'thaistyle', 'dressing', 'sweet', 'potato', 'stew', 'i', 'love', 'autumn', 'cooking', 'i', 'just', 'got', 'some', 'butternut', 'squash', 'in', 'my', 'csa', 'box', 'so', 'i', 'm', 'thinking', 'about', 'what', 'i', 'want', 'to', 'do', 'with', 'them', 'this', 'weekend', 'thinking', 'maybe', 'roasted', 'butternut', 'squash', 'risotto'], ['ooh', 'i', 'love', 'butternut', 'squash', 'risotto', 'apart', 'from', 'the', 'chopping', 'up', 'the', 'butternut', 'squash', 'part', 'have', 'nt', 'made', 'it', 'for', 'ages', 'that', 's', 'definitely', 'going', 'on', 'my', 'next', 'week', 's', 'menu', 'breakfast', 'crumpets', 'banana', 'lunch', 'cheese', 'shallot', 'toastie', 'apple', 'dinner', 'jacket', 'potato', 'beans', 'not', 'the', 'most', 'inspiring', 'food', 'day', 'today'], ['can', 'of', 'low', 'sodium', 'chicken', 'with', 'wild', 'rice', 'soup', 'with', 'an', 'added', '12', 'cup', 'of', 'brown', 'rice', 'and', 'a', 'side', 'of', 'crunchy', 'raw', 'organic', 'carrots'], ['breakfast', 'zoats', 'with', 'melted', 'american', 'cheese', 'and', 'salt', 'and', 'pepper', 'lunch', 'amy', 's', 'organic', 'tortilla', 'casserole', 'and', 'black', 'beans', 'microwave', 'dinner', 'with', 'the', 'rest', 'of', 'the', 'zucchini', 'from', 'breakfast', 'mixed', 'in', 'for', 'added', 'volume', 'dinner', '1', 'oz', 'pasta', 'with', 'roasted', 'orange', 'bell', 'pepper', 'steamed', 'corn', 'andor', 'peas', 'if', 'i', 'have', 'them', 'and', 'about', 'an', 'ounce', 'of', 'shredded', 'cheese', 'side', 'of', 'steamed', 'asparagus', 'i', 'buy', 'the', 'microwave', 'steam', 'in', 'bag', 'asparagus', 'and', 'dh', 'and', 'i', 'usually', 'eat', 'a', 'whole', 'bag', 'each', 'snacks', 'not', 'sure', 'yet', 'thinking', 'of', 'trying', 'an', 'angel', 'food', 'cake', 'recipe', 'i', 'found', 'yesterday'], ['today', 's', 'going', 'to', 'be', 'a', 'good', 'if', 'carby', 'day', 'i', 'think', 'breakfast', 'about', '23', 'of', 'a', 'carrot', 'muffin', 'amazing', 'cottage', 'cheese', 'with', 'peach', 'bellini', 'jam', 'coffee', 'lunch', 'will', 'be', 'turkey', 'and', 'cheddar', 'sandwiches', 'on', 'greenchili', 'sourdough', 'double', 'amazing', 'and', 'i', 'suspect', 'i', 'will', 'also', 'eat', 'at', 'least', 'one', 'slice', 'of', 'the', 'bread', 'topped', 'with', 'a', 'thin', 'slice', 'of', 'cheese', 'baby', 'carrots', 'and', 'cherry', 'tomatoes', 'on', 'the', 'side', 'dinner', 'either', 'leftover', 'spanish', 'rice', 'with', 'chickpeas', 'artichoke', 'hearts', 'and', 'greens', 'or', 'let', 's', 'be', 'honest', 'more', 'fancy', 'bread', 'cheese', 'and', 'turkey', 'with', 'a', 'token', 'side', 'of', 'green', 'beans', 'or', 'broccoli'], ['breakfast', 'home', 'made', 'plain', 'yoghurt', 'with', 'blueberries', 'strawberries', 'and', 'a', 'handful', 'of', 'kashi', 'granola', 'two', 'cups', 'of', 'coffee', 'post', 'run', 'snack', 'bunch', 'of', 'tangerines', 'lunch', 'sausage', 'and', 'bell', 'peppers', 'baked', 'in', 'the', 'oven', 'and', 'a', 'pita', 'i', 'might', 'add', 'some', 'sweet', 'potato', 'we', 'll', 'see', 'snacks', 'out', ...

# %% [markdown]
# **Remove Stopwords**

# %%
# Removing the stopwords
from nltk.corpus import stopwords

no_stop = []

for post in no_punc:
    new_term_vector = []
    for word in post:
        if not word in stopwords.words('english'):
            new_term_vector.append(word)
            
    no_stop.append(new_term_vector)
    
print(no_stop)
# Out:
# [['autumn', 'fully', 'arrived', 'cooking', 'breakfast', 'toaster', 'waffles', 'yogurt', 'butter', 'syrup', 'fried', 'ham', 'coffee', 'lunch', 'leftover', 'chili', 'cheese', 'sour', 'cream', 'corn', 'chips', 'fairly', 'small', 'portion', 'light', 'still', 'hungry', 'broccoli', 'baby', 'carrots', 'cherry', 'tomatoes', 'dinner', 'leftover', 'vegetableloaded', 'chickentortellini', 'soup', 'snacks', 'clementines', 'grapes', 'pomegranate'], ['breakfast', 'chinese', 'sticky', 'rice', 'tempeh', 'sausage', 'cucumber', 'salad', 'lunch', 'going', 'lunch', 'coworkers', 'probably', 'black', 'bean', 'burger', 'guacamole', 'fruit', 'salad', 'dinner', 'lettuce', 'basil', 'mint', 'radishes', 'thaistyle', 'dressing', 'sweet', 'potato', 'stew', 'love', 'autumn', 'cooking', 'got', 'butternut', 'squash', 'csa', 'box', 'thinking', 'want', 'weekend', 'thinking', 'maybe', 'roasted', 'butternut', 'squash', 'risotto'], ['ooh', 'love', 'butternut', 'squash', 'risotto', 'apart', 'chopping', 'butternut', 'squash', 'part', 'nt', 'made', 'ages', 'definitely', 'going', 'next', 'week', 'menu', 'breakfast', 'crumpets', 'banana', 'lunch', 'cheese', 'shallot', 'toastie', 'apple', 'dinner', 'jacket', 'potato', 'beans', 'inspiring', 'food', 'day', 'today'], ['low', 'sodium', 'chicken', 'wild', 'rice', 'soup', 'added', '12', 'cup', 'brown', 'rice', 'side', 'crunchy', 'raw', 'organic', 'carrots'], ['breakfast', 'zoats', 'melted', 'american', 'cheese', 'salt', 'pepper', 'lunch', 'amy', 'organic', 'tortilla', 'casserole', 'black', 'beans', 'microwave', 'dinner', 'rest', 'zucchini', 'breakfast', 'mixed', 'added', 'volume', 'dinner', '1', 'oz', 'pasta', 'roasted', 'orange', 'bell', 'pepper', 'steamed', 'corn', 'andor', 'peas', 'ounce', 'shredded', 'cheese', 'side', 'steamed', 'asparagus', 'buy', 'microwave', 'steam', 'bag', 'asparagus', 'dh', 'usually', 'eat', 'whole', 'bag', 'snacks', 'sure', 'yet', 'thinking', 'trying', 'angel', 'food', 'cake', 'recipe', 'found', 'yesterday'], ['today', 'going', 'good', 'carby', 'day', 'think', 'breakfast', '23', 'carrot', 'muffin', 'amazing', 'cottage', 'cheese', 'peach', 'bellini', 'jam', 'coffee', 'lunch', 'turkey', 'cheddar', 'sandwiches', 'greenchili', 'sourdough', 'double', 'amazing', 'suspect', 'also', 'eat', 'least', 'one', 'slice', 'bread', 'topped', 'thin', 'slice', 'cheese', 'baby', 'carrots', 'cherry', 'tomatoes', 'side', 'dinner', 'either', 'leftover', 'spanish', 'rice', 'chickpeas', 'artichoke', 'hearts', 'greens', 'let', 'honest', 'fancy', 'bread', 'cheese', 'turkey', 'token', 'side', 'green', 'beans', 'broccoli'], ['breakfast', 'home', 'made', 'plain', 'yoghurt', 'blueberries', 'strawberries', 'handful', 'kashi', 'granola', 'two', 'cups', 'coffee', 'post', 'run', 'snack', 'bunch', 'tangerines', 'lunch', 'sausage', 'bell', 'peppers', 'baked', 'oven', 'pita', 'might', 'add', 'sweet', 'potato', 'see', 'snacks', 'tub', 'carrots', 'cheese', 'grapes', 'nuts', 'crackers', 'dinner', 'getting', 'home', 'late', 'side', 'crazy', 'hungry', 'might', 'pick', 'something', 'hell', 'cals', 'today', 'thinking', 'tostada', 'salad', 'quesadilla', 'el', 'pollo', 'loco', 'week', 'lol', 'make', 'home', 'discipline', 'intact', 'microwave', 'rice', 'frozen', 'gyoza', 'broccoli', 'late', 'night', 'munchies', 'week', 'instead', 'halo', 'top', 'whatever', 'colder', 'enjoying', 'little', 'bowl', 'sliced', 'apples', 'walnuts', 'cashews', 'couple', 'chunks', 'parmesan', 'crackers'], ['breakfast', 'protein', 'plate', 'local', 'diner', '4', 'scrambled', 'eggs', '3', 'pieces', 'bacon', '2', 'slices', 'canadian', 'bacon', 'could', 'eat', 'half', 'eggs', 'lol', 'supper', 'grilled', 'cheese', 'cauliflower', 'sandwich', 'thins', 'stuffed', 'full', 'garlic', 'pepper', 'ham', 'little', 'bacon', 'provolone', 'cheddar', 'nice', 'big', 'salad', 'balsamic', 'vinaigrette'], ['ok', 'well', 'nice', 'plan', 'went', 'window', '10am', 'roast', 'beef', 'sandwich', 'crackers', 'runger', 'real'], ['breakfast', '2', 'homemade', 'cinnamon', 'rolls', 'morning', 'snack', 'an ...

# %% [markdown]
# **Stemming and Lemmatization**

# %%
# Stemming and Lemmatizing

from nltk.stem.porter import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

pstem = PorterStemmer()
wlem = WordNetLemmatizer()

preproc_text = []

for text in no_stop:
    final_text = []
    for word in text:
        pstem.stem(word)
        final_text.append(wlem.lemmatize(word))
    
    preproc_text.append(final_text)
    
print(preproc_text)
# Out:
# [['autumn', 'fully', 'arrived', 'cooking', 'breakfast', 'toaster', 'waffle', 'yogurt', 'butter', 'syrup', 'fried', 'ham', 'coffee', 'lunch', 'leftover', 'chili', 'cheese', 'sour', 'cream', 'corn', 'chip', 'fairly', 'small', 'portion', 'light', 'still', 'hungry', 'broccoli', 'baby', 'carrot', 'cherry', 'tomato', 'dinner', 'leftover', 'vegetableloaded', 'chickentortellini', 'soup', 'snack', 'clementine', 'grape', 'pomegranate'], ['breakfast', 'chinese', 'sticky', 'rice', 'tempeh', 'sausage', 'cucumber', 'salad', 'lunch', 'going', 'lunch', 'coworkers', 'probably', 'black', 'bean', 'burger', 'guacamole', 'fruit', 'salad', 'dinner', 'lettuce', 'basil', 'mint', 'radish', 'thaistyle', 'dressing', 'sweet', 'potato', 'stew', 'love', 'autumn', 'cooking', 'got', 'butternut', 'squash', 'csa', 'box', 'thinking', 'want', 'weekend', 'thinking', 'maybe', 'roasted', 'butternut', 'squash', 'risotto'], ['ooh', 'love', 'butternut', 'squash', 'risotto', 'apart', 'chopping', 'butternut', 'squash', 'part', 'nt', 'made', 'age', 'definitely', 'going', 'next', 'week', 'menu', 'breakfast', 'crumpet', 'banana', 'lunch', 'cheese', 'shallot', 'toastie', 'apple', 'dinner', 'jacket', 'potato', 'bean', 'inspiring', 'food', 'day', 'today'], ['low', 'sodium', 'chicken', 'wild', 'rice', 'soup', 'added', '12', 'cup', 'brown', 'rice', 'side', 'crunchy', 'raw', 'organic', 'carrot'], ['breakfast', 'zoats', 'melted', 'american', 'cheese', 'salt', 'pepper', 'lunch', 'amy', 'organic', 'tortilla', 'casserole', 'black', 'bean', 'microwave', 'dinner', 'rest', 'zucchini', 'breakfast', 'mixed', 'added', 'volume', 'dinner', '1', 'oz', 'pasta', 'roasted', 'orange', 'bell', 'pepper', 'steamed', 'corn', 'andor', 'pea', 'ounce', 'shredded', 'cheese', 'side', 'steamed', 'asparagus', 'buy', 'microwave', 'steam', 'bag', 'asparagus', 'dh', 'usually', 'eat', 'whole', 'bag', 'snack', 'sure', 'yet', 'thinking', 'trying', 'angel', 'food', 'cake', 'recipe', 'found', 'yesterday'], ['today', 'going', 'good', 'carby', 'day', 'think', 'breakfast', '23', 'carrot', 'muffin', 'amazing', 'cottage', 'cheese', 'peach', 'bellini', 'jam', 'coffee', 'lunch', 'turkey', 'cheddar', 'sandwich', 'greenchili', 'sourdough', 'double', 'amazing', 'suspect', 'also', 'eat', 'least', 'one', 'slice', 'bread', 'topped', 'thin', 'slice', 'cheese', 'baby', 'carrot', 'cherry', 'tomato', 'side', 'dinner', 'either', 'leftover', 'spanish', 'rice', 'chickpea', 'artichoke', 'heart', 'green', 'let', 'honest', 'fancy', 'bread', 'cheese', 'turkey', 'token', 'side', 'green', 'bean', 'broccoli'], ['breakfast', 'home', 'made', 'plain', 'yoghurt', 'blueberry', 'strawberry', 'handful', 'kashi', 'granola', 'two', 'cup', 'coffee', 'post', 'run', 'snack', 'bunch', 'tangerine', 'lunch', 'sausage', 'bell', 'pepper', 'baked', 'oven', 'pita', 'might', 'add', 'sweet', 'potato', 'see', 'snack', 'tub', 'carrot', 'cheese', 'grape', 'nut', 'cracker', 'dinner', 'getting', 'home', 'late', 'side', 'crazy', 'hungry', 'might', 'pick', 'something', 'hell', 'cals', 'today', 'thinking', 'tostada', 'salad', 'quesadilla', 'el', 'pollo', 'loco', 'week', 'lol', 'make', 'home', 'discipline', 'intact', 'microwave', 'rice', 'frozen', 'gyoza', 'broccoli', 'late', 'night', 'munchies', 'week', 'instead', 'halo', 'top', 'whatever', 'colder', 'enjoying', 'little', 'bowl', 'sliced', 'apple', 'walnut', 'cashew', 'couple', 'chunk', 'parmesan', 'cracker'], ['breakfast', 'protein', 'plate', 'local', 'diner', '4', 'scrambled', 'egg', '3', 'piece', 'bacon', '2', 'slice', 'canadian', 'bacon', 'could', 'eat', 'half', 'egg', 'lol', 'supper', 'grilled', 'cheese', 'cauliflower', 'sandwich', 'thins', 'stuffed', 'full', 'garlic', 'pepper', 'ham', 'little', 'bacon', 'provolone', 'cheddar', 'nice', 'big', 'salad', 'balsamic', 'vinaigrette'], ['ok', 'well', 'nice', 'plan', 'went', 'window', '10am', 'roast', 'beef', 'sandwich', 'cracker', 'runger', 'real'], ['breakfast', '2', 'homemade', 'cinnamon', 'roll', 'morning', 'snack', 'another', 'cinnamon', 'roll', 'late', 'lunchearly', ...

# %%
# create final data set
data = raw_data.copy()

new_col = pd.Series(preproc_text)
data['post'] = new_col
data.head(10)
# Out:
#                 user                     date  \
# 0              avskk  October 24, 2018 2:32PM
# 1      janejellyroll  October 24, 2018 2:37PM
# 2         firlena227  October 24, 2018 4:07PM
# 3           amy19355  November 2, 2018 3:30PM
# 4  Sunshine_And_Sand  November 2, 2018 3:38PM
# 5              avskk  November 2, 2018 4:42PM
# 6        MelanieCN77  November 3, 2018 2:00PM
# 7   nicsflyingcircus  November 3, 2018 4:31PM
# 8        MelanieCN77  November 3, 2018 5:10PM
# 9     rainingribbons  November 3, 2018 8:01PM
#
#                                                 post
# 0  [autumn, fully, arrived, cooking, breakfast, t...
# 1  [breakfast, chinese, sticky, rice, tempeh, sau...
# 2  [ooh, love, butternut, squash, risotto, apart,...
# 3  [low, sodium, chicken, wild, rice, soup, added...
# 4  [breakfast, zoats, melted, american, cheese, s...
# 5  [today, going, good, carby, day, think, breakf...
# 6  [breakfast, home, made, plain, yoghurt, bluebe...
# 7  [breakfast, protein, plate, local, diner, 4, s...
# 8  [ok, well, nice, plan, went, window, 10am, roa...
# 9  [breakfast, 2, homemade, cinnamon, roll, morni...

# %%
# save processed data to csv
#data.to_csv(r'mfp_1_proc_data.csv', index=False,header=True, encoding='utf-8')

# %%
# Function to streamline NLP Process

def nlp(file):
    # Load Dataset
    raw_data = pd.read_csv(file + '.csv')
    
    # Convert to lowercase
    raw_data['post'] = [post.lower() for post in raw_data['post']]

    # Word & Sentence Tokenization
    token_post = [word_tokenize(post) for post in raw_data['post']]

    sent_token = [sent_tokenize(post) for post in raw_data['post']]
    
    # Remove Punctuation
    reg = re.compile('(@[a-z0-9]+)|([^0-9a-z \t])|(\w+:\/\/\S+)')

    no_punc = []

    for filt in token_post:
        review = []
        for token in filt:
            new_token = reg.sub(u'', token)
            if not new_token == u'':
                review.append(new_token)
        no_punc.append(review)
        
    # Remove Stopwords
    no_stop = []

    for post in no_punc:
        new_term_vector = []
        for word in post:
            if not word in stopwords.words('english'):
                new_term_vector.append(word)

        no_stop.append(new_term_vector)
        
    # Stemming & Lemmatization
    pstem = PorterStemmer()
    wlem = WordNetLemmatizer()

    preproc_text = []

    for text in no_stop:
        final_text = []
        for word in text:
            pstem.stem(word)
            final_text.append(wlem.lemmatize(word))

        preproc_text.append(final_text)
        
    # create final data set
    data = raw_data.copy()

    new_col = pd.Series(preproc_text)
    data['post'] = new_col
    print(data.head(5))
    
    # save processed data to csv
    data.to_csv(file + '_proc.csv', index=False,header=True, encoding='utf-8')

# %%
# Process & save data sets

files = ['mfp_data34', 'mfp_data38', 'mfp_data41'] 

for i in files:
    nlp(i)
# Out:
#                 user                    date  \
# 0          nooshi713  March 12, 2019 10:05PM
# 1           JennJ323   March 13, 2019 1:56PM
# 2     seltzermint555   March 13, 2019 3:26PM
# 3  Sunshine_And_Sand   March 13, 2019 7:39PM
# 4          nooshi713   March 13, 2019 7:41PM
#
#                                                 post
# 0  [breakfast, tea, 12, tbsp, agave, 1, scrambled...
# 1  [breakfast, homestyle, frozen, waffle, x2, oni...
# 2  [breakfast, oatmeal, peanut, butter, strawberr...
# 3  [breakfast, oatmeal, shredded, zucchini, melte...
# 4  [breakfast, 2, scrambled, egg, tangerine, tea,...
#              user                   date  \
# 0        JennJ323   April 2, 2019 3:12PM
# 1        lalee115   April 2, 2019 3:16PM
# 2      my3sons527  April 2, 2019 11:17PM
# 3        JennJ323   April 4, 2019 7:07PM
# 4  seltzermint555   April 4, 2019 7:50PM
#
#                                                 post
# 0  [breakfast, 2, turkey, sausage, link, hard, bo...
# 1  [jennj323, wrote, breakfast, 2, turkey, sausag...
# 2  [b, jimmy, dean, delight, raspberry, l, huge, ...
# 3  [lalee115, wrote, jennj323, wrote, breakfast, ...
# 4  [breakfast, 3, oz, blackberry, 12, avocado, wh...
#               user                 date  \
# 0   seltzermint555  May 15, 2019 2:22PM
# 1        tmpecus78  May 15, 2019 2:26PM
# 2  NewLIFEstyle4ME  May 15, 2019 5:32PM
# 3  NewLIFEstyle4ME  May 16, 2019 6:41PM
# 4   seltzermint555  May 16, 2019 6:56PM
#
#                                                 post
# 0  [breakfast, hard, boiled, egg, toaster, waffle...
# 1  [today, meal, consist, 6, whole, egg, cooked, ...
# 2  [breakfast, avocalado, smoothie, avocado, big,...
# 3  [breakfast, 1, cup, roasted, dandelion, root, ...
# 4  [breakfast, boiled, egg, 12, avocado, 2, oz, r...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# ## Term Frequency-Inverse Document Frequency (TF-IDF)

# %%
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer as tfi
from sklearn.decomposition import PCA
from sklearn.preprocessing import normalize
from sklearn.metrics import pairwise_distances

tf_idf_vect = tfi(stop_words = 'english',
                 max_features = 20)

x = data['post']

#data = [tweets.strip() for tweets in cleaned_data['text']]
#texts = [[word.lower() for word in tweet.split()]]
         
tf_idf = tf_idf_vect.fit_transform([' '.join(post) for post in x])
tf_idf_norm = normalize(tf_idf)
tf_idf_array = tf_idf_norm.toarray()

tf_data = pd.DataFrame(tf_idf_array,
                     columns = tf_idf_vect.get_feature_names())
tf_data.head(15)
# Out:
#         bean  breakfast    butter    carrot    cheese    coffee       cup  \
# 0   0.000000   0.208507  0.372521  0.372521  0.310581  0.328878  0.000000
# 1   0.323362   0.205010  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.428627   0.271747  0.000000  0.000000  0.404781  0.000000  0.000000
# 3   0.000000   0.000000  0.000000  0.395381  0.000000  0.000000  0.370769
# 4   0.307131   0.389438  0.000000  0.000000  0.580087  0.000000  0.000000
# 5   0.176792   0.112085  0.000000  0.400506  0.500869  0.176792  0.000000
# 6   0.000000   0.178669  0.000000  0.319212  0.266136  0.281815  0.299342
# 7   0.000000   0.270614  0.000000  0.000000  0.403093  0.000000  0.000000
# 8   0.000000   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.339680   0.215356  0.000000  0.000000  0.320783  0.000000  0.000000
# 10  0.000000   0.199385  0.000000  0.000000  0.000000  0.314490  0.334049
# 11  0.000000   0.187824  0.000000  0.000000  0.000000  0.296255  0.314680
# 12  0.000000   0.129994  0.232249  0.232249  0.000000  0.205039  0.000000
# 13  0.300619   0.190591  0.340512  0.000000  0.283894  0.300619  0.000000
# 14  0.000000   0.187824  0.000000  0.000000  0.000000  0.296255  0.314680
#
#          day    dinner       eat     green     lunch    potato      rice  \
# 0   0.000000  0.218433  0.000000  0.000000  0.240169  0.000000  0.000000
# 1   0.000000  0.214769  0.000000  0.000000  0.472281  0.305372  0.343473
# 2   0.485507  0.284684  0.000000  0.000000  0.313012  0.404781  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.741538
# 4   0.000000  0.407978  0.326232  0.000000  0.224287  0.000000  0.000000
# 5   0.200253  0.117421  0.187787  0.429286  0.129105  0.000000  0.187787
# 6   0.000000  0.187175  0.000000  0.000000  0.205800  0.266136  0.299342
# 7   0.000000  0.000000  0.453387  0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.384757  0.225608  0.000000  0.412406  0.000000  0.320783  0.000000
# 10  0.000000  0.208877  0.334049  0.000000  0.229662  0.000000  0.000000
# 11  0.335568  0.196765  0.314680  0.000000  0.216345  0.000000  0.000000
# 12  0.000000  0.136182  0.000000  0.000000  0.149733  0.193632  0.435583
# 13  0.000000  0.199664  0.000000  0.364981  0.219532  0.283894  0.319315
# 14  0.335568  0.196765  0.314680  0.000000  0.216345  0.000000  0.000000
#
#        salad  sandwich     slice     snack      soup    yogurt
# 0   0.000000  0.000000  0.000000  0.328878  0.372521  0.349332
# 1   0.610744  0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000  0.000000  0.395381  0.000000
# 4   0.000000  0.000000  0.000000  0.307131  0.000000  0.000000
# 5   0.000000  0.166956  0.400506  0.000000  0.000000  0.000000
# 6   0.266136  0.000000  0.000000  0.563629  0.000000  0.000000
# 7   0.403093  0.403093  0.483483  0.000000  0.000000  0.000000
# 8   0.000000  1.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.384757  0.339680  0.000000  0.000000
# 10  0.296994  0.296994  0.356224  0.000000  0.356224  0.334049
# 11  0.279773  0.279773  0.335568  0.000000  0.335568  0.314680
# 12  0.193632  0.000000  0.000000  0.205039  0.696746  0.000000
# 13  0.000000  0.283894  0.000000  0.000000  0.000000  0.319315
# 14  0.279773  0.279773  0.335568  0.000000  0.335568  0.314680

# %%
tf_data.describe()
# Out:
#             bean  breakfast     butter     carrot     cheese     coffee  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    0.134441   0.180743   0.106685   0.097916   0.165691   0.104769
# std     0.193761   0.133612   0.184546   0.161732   0.206819   0.140567
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.129994   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.187824   0.000000   0.000000   0.000000   0.000000
# 75%     0.300619   0.208507   0.232249   0.232249   0.320783   0.281815
# max     0.650093   0.572184   0.538514   0.400506   0.580087   0.328878
#
#              cup        day     dinner        eat      green      lunch  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    0.142628   0.115616   0.166466   0.105542   0.104327   0.152526
# std     0.234354   0.204858   0.119389   0.158826   0.205938   0.128872
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.117421   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.196765   0.000000   0.000000   0.196326
# 75%     0.314680   0.200253   0.214769   0.285561   0.000000   0.219532
# max     0.856684   0.686279   0.407978   0.453387   0.721096   0.472281
#
#           potato       rice      salad   sandwich      slice      snack  \
# count  21.000000  21.000000  21.000000  21.000000  21.000000  21.000000
# mean    0.127577   0.124409   0.135004   0.153115   0.109338   0.155193
# std     0.158679   0.205052   0.178166   0.240044   0.179340   0.218261
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.266136   0.285561   0.279773   0.279773   0.335568   0.328878
# max     0.426148   0.741538   0.610744   1.000000   0.483483   0.605878
#
#             soup     yogurt
# count  21.000000  21.000000
# mean    0.118667   0.111502
# std     0.204566   0.166624
# min     0.000000   0.000000
# 25%     0.000000   0.000000
# 50%     0.000000   0.000000
# 75%     0.335568   0.314680
# max     0.696746   0.479318

# %%
stuff = pd.read_csv('mfp_1_proc_data.csv')
stuff.head()
# Out:
#                 user                     date  \
# 0              avskk  October 24, 2018 2:32PM
# 1      janejellyroll  October 24, 2018 2:37PM
# 2         firlena227  October 24, 2018 4:07PM
# 3           amy19355  November 2, 2018 3:30PM
# 4  Sunshine_And_Sand  November 2, 2018 3:38PM
#
#                                                 post
# 0  ['autumn', 'fully', 'arrived', 'cooking', 'bre...
# 1  ['breakfast', 'chinese', 'sticky', 'rice', 'te...
# 2  ['ooh', 'love', 'butternut', 'squash', 'risott...
# 3  ['low', 'sodium', 'chicken', 'wild', 'rice', '...
# 4  ['breakfast', 'zoats', 'melted', 'american', '...
